# %% [markdown]
# <h2>Gatheing Data</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# <h2>Explarotary Data Analysis</h2>

# %%
sns.jointplot(x="horsepower", y="price", data=df, alpha=0.5)

# %% [markdown]
# There is a faint correlation

# %%
sns.jointplot(x="peakrpm", y="price", data=df, alpha=0.5)

# %% [markdown]
# Nothing intresting here

# %%
attributes2 = ['boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg', 'price']
# 'symboling','wheelbase','carlength','carwidth','carheight','curbweight','enginesize'
# Compute the correlation matrix
correlation_matrix = df[attributes2].corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)

# Add title
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# **Price** has high correlation with **horsepower**, **boreratio**

# %%
attributes1 = ['symboling','wheelbase','carlength','carwidth','carheight','curbweight','enginesize', 'price']

# Compute the correlation matrix
correlation_matrix = df[attributes1].corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)

# Add title
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# **Price** has high correlation with **enginesize**, **curbweight**, **carwidth**, **carlength**, **wheelbase**

# %%
# Columns effecting the price the most
attributes = ['wheelbase','carlength','carwidth','curbweight','enginesize', 'boreratio','horsepower', 'price']

sns.pairplot(df[attributes], kind='scatter', plot_kws={'alpha': 0.4})

# %%
sns.lmplot(x="enginesize", y="price", data=df, scatter_kws={'alpha': 0.3})

# %% [markdown]
# <h2>Splitting the Data</h2>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['price'], axis=1)
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <h2>Creating Pipeline</h2>

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
#processing numeric values
num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #if there is a mising value i will fill it with a median robust t outliers
    ('scale', StandardScaler()) #normalize the data scale 
])

#processing categorical values
cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), #filling missing values with the most frequent one
    ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore')) # make a matrix of 1 and 0 for each unique value
])

# %%
num_val = X_train.select_dtypes(include=[np.number]).columns
cat_val = X_train.select_dtypes(include=["object"]).columns

preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, num_val),
    ('cat', cat_transformer, cat_val)
], remainder='drop')

# %% [markdown]
# <h2>Stochastic GD</h2>

# %%
from sklearn.linear_model import SGDRegressor

complete_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', SGDRegressor(max_iter=1000, tol=1e-5, eta0=0.01, n_iter_no_change=100, random_state=42))
])

# %%
complete_pipeline.fit(X_train,y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       d...
# ...

# %% [markdown]
# <h4>Predictions</h4>

# %%
prediction=complete_pipeline.predict(X_test)
prediction
# Out:
# array([28341.31276852, 19215.64366253, 10040.37616834, 14779.19061828,
#        26599.8552182 ,  5627.19778234,  7522.46513545,  7948.45380593,
#         9476.46375649,  7485.41957368, 14709.62531416,  6387.7543526 ,
#        17090.87769353,  8065.16250154, 39817.15106646,  6421.57882162,
#        -2886.01890412, 13356.48176921, 10340.35794554, 10965.56140676,
#        11620.38557226, 18214.57293258,  9457.85587172,  3239.43028703,
#         8076.9133824 , 28402.82547178, 16901.53659002, 15259.82292972,
#         4597.26927466, 16053.40938664, 27024.43811309,  6371.6902314 ,
#         5159.79959828, 19510.40660521,  7143.43119476, 29525.58013672,
#        12490.07944765, 11607.9400606 ,  7449.36521139, 14694.72914503,
#         7310.53685631, 15273.82956301, 17427.3055781 ,  5431.751736  ,
#         6872.43298639,  8772.45841174,  7380.39600779,  6980.82230356,
#        16766.07194675, 14670.97661795,  6692.00880531, 19574.92792354,
# ...

# %% [markdown]
# <h4>Evaluation</h4>

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import math

# %%
sns.scatterplot(x=prediction, y=y_test)
plt.title('Evaluation of our Model')
plt.xlabel('Predictions')
# Out:
# Text(0.5, 0, 'Predictions')

# %%
print("Mean Absolute Error: ", mean_absolute_error(y_test, prediction))
print("Mean Squared Error: ", mean_squared_error(y_test, prediction))
print("Root Mean Squared Error RMSE: ", math.sqrt(mean_squared_error(y_test, prediction)))
# Out:
# Mean Absolute Error:  2002.1544117311385
# Mean Squared Error:  9256053.732473953
# Root Mean Squared Error RMSE:  3042.376329856968

# %%
r2=r2_score(y_test,prediction)
r2
# Out:
# 0.8664048964860407

# %%
comparison=y_test.copy()
comparison=pd.DataFrame(comparison)
comparison['Predicted Values']=np.round(prediction,2)
comparison
# Out:
#          price  Predicted Values
# 15   30760.000          28341.31
# 9    17859.167          19215.64
# 100   9549.000          10040.38
# 132  11850.000          14779.19
# 68   28248.000          26599.86
# ..         ...               ...
# 56   11845.000          11951.42
# 128  37028.000          29631.04
# 76    5389.000           6451.41
# 144   9233.000           9836.28
# 104  17199.000          18638.99
#
# [62 rows x 2 columns]

# %%
sns.regplot(x="price", y="Predicted Values", data=comparison, line_kws={'color': 'red', 'linewidth': 2})

plt.show()

# %% [markdown]
# <h2>Batch GD</h2>

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler())
        ]), num_val),
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), cat_val)
    ]
)

# Preprocess the data
X_train_processed = preprocessor.fit_transform(X_train)
y_train_processed = np.array(y_train).flatten()

# %%
# Batch Gradient Descent Implementation
class BatchGradientDescent:
    def __init__(self, learning_rate=0.01, max_iter=1000, tol=1e-5):
        self.learning_rate = learning_rate
        self.max_iter = max_iter
        self.tol = tol
        self.theta = None

    def fit(self, X, y):
        m, n = X.shape
        self.theta = np.zeros(n)  # Initialize weights
        for iteration in range(self.max_iter):
            predictions = X.dot(self.theta)
            errors = predictions - y
            gradient = (1 / m) * X.T.dot(errors)  # Compute gradient
            prev_theta = self.theta.copy()
            self.theta -= self.learning_rate * gradient  # Update weights
            # Check convergence
            if np.linalg.norm(self.theta - prev_theta, ord=2) < self.tol:
                print(f"Converged after {iteration + 1} iterations")
                break

    def predict(self, X):
        return X.dot(self.theta)

# %%
# Train the model
bgd_model = BatchGradientDescent(learning_rate=0.01, max_iter=1000)
bgd_model.fit(X_train_processed, y_train_processed)
X_test_processed = preprocessor.transform(X_test)

# %%
y_pred = bgd_model.predict(X_test_processed)

# %%
y_pred
# Out:
# array([28871.87085238, 17718.96809682, 10226.42196209, 14867.69910925,
#        25546.40531407,  5396.91400283,  6305.56428041,  6791.17965323,
#         9518.82419401,  8475.29114344, 14672.4374129 ,  6619.69061891,
#        18065.37622972,  7810.67840298, 37929.17729725,  4620.89380857,
#        -4448.02492216, 14543.17863484, 10685.6837094 , 10651.66471141,
#        11613.30389816, 20576.30163807,  7495.61719884,  1658.02065727,
#         7422.37362834, 29309.82083964, 15472.88271071, 16301.80287726,
#         4931.03544253, 16755.32443526, 26059.07978531,  4894.38402491,
#         4826.95938152, 21340.35244974,  6056.17315955, 26567.98343206,
#        10434.18105787,  9471.09293211,  6236.94240881, 14771.25975369,
#         7618.71030932, 15138.15281518, 17700.59961957,  4705.82797112,
#         6753.84905172,  8771.72839445,  6147.17624931,  7366.32145718,
#        16783.89210007, 15175.57970223,  5694.80648869, 20463.57682923,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import math
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error RMSE: ", math.sqrt(mean_squared_error(y_test, y_pred)))
r2=r2_score(y_test,y_pred)
r2
# Out:
# Mean Absolute Error:  2358.961084283558
# Mean Squared Error:  11930004.119763102
# Root Mean Squared Error RMSE:  3453.983804212623
# 0.8278110541093708

# %%
comparison2=y_test.copy()
comparison2=pd.DataFrame(comparison2)
comparison2['Predicted Values']=np.round(y_pred,2)
comparison2
# Out:
#          price  Predicted Values
# 15   30760.000          28871.87
# 9    17859.167          17718.97
# 100   9549.000          10226.42
# 132  11850.000          14867.70
# 68   28248.000          25546.41
# ..         ...               ...
# 56   11845.000           9532.95
# 128  37028.000          25554.43
# 76    5389.000           5696.42
# 144   9233.000          10077.62
# 104  17199.000          21794.06
#
# [62 rows x 2 columns]

# %%
sns.regplot(x="price", y="Predicted Values", data=comparison2, line_kws={'color': 'red', 'linewidth': 2})

plt.show()
